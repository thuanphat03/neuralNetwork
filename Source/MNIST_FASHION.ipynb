# %% [markdown]
# # MSSV: 21127666
# # Họ và tên: Trần Thuận Phát

# %% [markdown]
# ## Import the required libraries

# %%
import numpy as np         
import pandas as pd
import matplotlib.pyplot as plt      
import random                        

from keras.datasets import fashion_mnist     
from keras.models import Sequential  

from keras.layers import Dense, Dropout, Activation   
from keras import utils
# Out:
# WARNING:tensorflow:From c:\Users\Acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Load the Dataset

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

print("X_train shape", X_train.shape)
print("y_train shape", y_train.shape)
print("X_test shape", X_test.shape)
print("y_test shape", y_test.shape)
# Out:
# X_train shape (60000, 28, 28)
# y_train shape (60000,)
# X_test shape (10000, 28, 28)
# y_test shape (10000,)

# %%
test_data = pd.read_csv('data_mnist_fashion/test.csv', delimiter = ',', header = 0, usecols = [x for x in range(1, 785)])

# %% [markdown]
# We load the dataset and verify the dimensions of the training and testing sets.

# %%
for i in range(9):
    plt.subplot(3,3,i+1)
    num = random.randint(0, len(X_train))
    plt.imshow(X_train[num], cmap='gray', interpolation='none')
    plt.title("Class {}".format(y_train[num]))
    
plt.tight_layout()

# %% [markdown]
# ## Data Preprocessing

# %%
X_train = X_train.reshape(60000, 784) 
X_test = X_test.reshape(10000, 784)   

X_train = X_train.astype('float32')   
X_test = X_test.astype('float32')

X_train /= 255                        
X_test /= 255

print("Training matrix shape", X_train.shape)
print("Testing matrix shape", X_test.shape)
# Out:
# Training matrix shape (60000, 784)
# Testing matrix shape (10000, 784)

# %% [markdown]
# # Convert to one-hot encoding

# %%
no_classes = 10

Y_train = utils.to_categorical(y_train, no_classes)
Y_test = utils.to_categorical(y_test, no_classes)

# %% [markdown]
# ## One Layer And 100 Nodes

# %%
model_1_layer_100_nodes = Sequential()
model_1_layer_100_nodes.add(Dense(100, input_shape=(784,))) 
model_1_layer_100_nodes.add(Activation('relu'))
model_1_layer_100_nodes.add(Dropout(0.2))
model_1_layer_100_nodes.add(Dense(10))
model_1_layer_100_nodes.add(Activation('softmax'))
model_1_layer_100_nodes.summary()
model_1_layer_100_nodes.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history_1_layer_100_nodes = model_1_layer_100_nodes.fit(X_train, Y_train, batch_size=128, epochs=10, verbose=1, validation_data=(X_test, Y_test))
# Out:
# WARNING:tensorflow:From c:\Users\Acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               78500
#
#  activation (Activation)     (None, 100)               0
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 10)                1010
#
#  activation_1 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 79510 (310.59 KB)
# Trainable params: 79510 (310.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# WARNING:tensorflow:From c:\Users\Acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\Acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6165 - accuracy: 0.7867 - val_loss: 0.4675 - val_accuracy: 0.8357
# Epoch 2/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.4325 - accuracy: 0.8480 - val_loss: 0.4191 - val_accuracy: 0.8514
# Epoch 3/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3918 - accuracy: 0.8590 - val_loss: 0.3936 - val_accuracy: 0.8560
# Epoch 4/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3657 - accuracy: 0.8684 - val_loss: 0.3733 - val_accuracy: 0.8641
# Epoch 5/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3490 - accuracy: 0.8735 - val_loss: 0.3640 - val_accuracy: 0.8677
# Epoch 6/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3356 - accuracy: 0.8785 - val_loss: 0.3542 - val_accuracy: 0.8718
# Epoch 7/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3258 - accuracy: 0.8829 - val_loss: 0.3497 - val_accuracy: 0.8744
# Epoch 8/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3166 - accuracy: 0.8842 - val_loss: 0.3420 - val_accuracy: 0.8795
# Epoch 9/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3068 - accuracy: 0.8876 - val_loss: 0.3512 - val_accuracy: 0.8729
# Epoch 10/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3017 - accuracy: 0.8898 - val_loss: 0.3418 - val_accuracy: 0.8767

# %% [markdown]
# ## Evaluate the model

# %%
loss, accuracy = model_1_layer_100_nodes.evaluate(X_test, Y_test, verbose=0)
print('Test accuracy:', accuracy)
# Out:
# Test accuracy: 0.8766999840736389

# %% [markdown]
# Plot the accuracy and loss metrics of the model.

# %%
fig = plt.figure()
plt.subplot(2,1,1)
plt.plot(history_1_layer_100_nodes.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(history_1_layer_100_nodes.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()

# %%
predicted_classes = model_1_layer_100_nodes.predict(X_test)
predicted_classes = [np.argmax(softmaxArray) for softmaxArray in predicted_classes]
Y_True = [np.argmax(softmaxArray) for softmaxArray in Y_test]

correct_indices = np.where(np.array(predicted_classes) == np.array(Y_True))[0]
incorrect_indices = np.where(np.array(predicted_classes) != np.array(Y_True))[0]
# Out:
# 313/313 [==============================] - 0s 811us/step

# %%
plt.figure()
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[correct].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[correct], y_test[correct]))
plt.suptitle("Correct Predictions")  
plt.tight_layout()
    
plt.figure()
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[incorrect].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[incorrect], y_test[incorrect]))
plt.suptitle("Incorrect Predictions")
plt.tight_layout()

# %% [markdown]
# ## One Layer And 300 Nodes

# %%
model_1_layer_300_nodes = Sequential()
model_1_layer_300_nodes.add(Dense(300, input_shape=(784,))) 
model_1_layer_300_nodes.add(Activation('relu'))
model_1_layer_300_nodes.add(Dropout(0.2))
model_1_layer_300_nodes.add(Dense(10))
model_1_layer_300_nodes.add(Activation('softmax'))
model_1_layer_300_nodes.summary()
model_1_layer_300_nodes.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history_1_layer_300_nodes = model_1_layer_300_nodes.fit(X_train, Y_train, batch_size=128, epochs=10, verbose=1, validation_data=(X_test, Y_test))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 300)               235500
#
#  activation_2 (Activation)   (None, 300)               0
#
#  dropout_1 (Dropout)         (None, 300)               0
#
#  dense_3 (Dense)             (None, 10)                3010
#
#  activation_3 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 238510 (931.68 KB)
# Trainable params: 238510 (931.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.5396 - accuracy: 0.8107 - val_loss: 0.4358 - val_accuracy: 0.8435
# Epoch 2/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3951 - accuracy: 0.8593 - val_loss: 0.3906 - val_accuracy: 0.8584
# Epoch 3/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3548 - accuracy: 0.8731 - val_loss: 0.3650 - val_accuracy: 0.8698
# Epoch 4/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3338 - accuracy: 0.8786 - val_loss: 0.3510 - val_accuracy: 0.8719
# Epoch 5/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3165 - accuracy: 0.8849 - val_loss: 0.3557 - val_accuracy: 0.8718
# Epoch 6/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3040 - accuracy: 0.8875 - val_loss: 0.3420 - val_accuracy: 0.8752
# Epoch 7/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2898 - accuracy: 0.8935 - val_loss: 0.3380 - val_accuracy: 0.8789
# Epoch 8/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2805 - accuracy: 0.8967 - val_loss: 0.3418 - val_accuracy: 0.8799
# Epoch 9/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2736 - accuracy: 0.8991 - val_loss: 0.3187 - val_accuracy: 0.8832
# Epoch 10/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2629 - accuracy: 0.9015 - val_loss: 0.3277 - val_accuracy: 0.8789

# %% [markdown]
# ## Evaluate the model

# %%
loss, accuracy = model_1_layer_300_nodes.evaluate(X_test, Y_test, verbose=0)
print('Test accuracy:', accuracy)
# Out:
# Test accuracy: 0.8788999915122986

# %% [markdown]
# Plot the accuracy and loss metrics of the model.

# %%
fig = plt.figure()
plt.subplot(2,1,1)
plt.plot(history_1_layer_300_nodes.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(history_1_layer_300_nodes.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()

# %%
predicted_classes = model_1_layer_300_nodes.predict(X_test)
predicted_classes = [np.argmax(softmaxArray) for softmaxArray in predicted_classes]
Y_True = [np.argmax(softmaxArray) for softmaxArray in Y_test]

correct_indices = np.where(np.array(predicted_classes) == np.array(Y_True))[0]
incorrect_indices = np.where(np.array(predicted_classes) != np.array(Y_True))[0]
# Out:
# 313/313 [==============================] - 0s 983us/step

# %%
plt.figure()
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[correct].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[correct], y_test[correct]))
plt.suptitle("Correct Predictions")  
plt.tight_layout()
    
plt.figure()
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[incorrect].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[incorrect], y_test[incorrect]))
plt.suptitle("Incorrect Predictions")
plt.tight_layout()

# %% [markdown]
# ## One Layer And 500 Nodes

# %%
model_1_layer_500_nodes = Sequential()
model_1_layer_500_nodes.add(Dense(500, input_shape=(784,))) 
model_1_layer_500_nodes.add(Activation('relu'))
model_1_layer_500_nodes.add(Dropout(0.2))
model_1_layer_500_nodes.add(Dense(10))
model_1_layer_500_nodes.add(Activation('softmax'))
model_1_layer_500_nodes.summary()
model_1_layer_500_nodes.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history_1_layer_500_nodes = model_1_layer_500_nodes.fit(X_train, Y_train, batch_size=128, epochs=10, verbose=1, validation_data=(X_test, Y_test))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 500)               392500
#
#  activation_4 (Activation)   (None, 500)               0
#
#  dropout_2 (Dropout)         (None, 500)               0
#
#  dense_5 (Dense)             (None, 10)                5010
#
#  activation_5 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 397510 (1.52 MB)
# Trainable params: 397510 (1.52 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5246 - accuracy: 0.8152 - val_loss: 0.4309 - val_accuracy: 0.8433
# Epoch 2/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3879 - accuracy: 0.8607 - val_loss: 0.3862 - val_accuracy: 0.8636
# Epoch 3/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3490 - accuracy: 0.8733 - val_loss: 0.3811 - val_accuracy: 0.8579
# Epoch 4/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3248 - accuracy: 0.8807 - val_loss: 0.3763 - val_accuracy: 0.8592
# Epoch 5/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3058 - accuracy: 0.8890 - val_loss: 0.3447 - val_accuracy: 0.8768
# Epoch 6/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2965 - accuracy: 0.8904 - val_loss: 0.3406 - val_accuracy: 0.8767
# Epoch 7/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2838 - accuracy: 0.8960 - val_loss: 0.3429 - val_accuracy: 0.8769
# Epoch 8/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2737 - accuracy: 0.8987 - val_loss: 0.3245 - val_accuracy: 0.8828
# Epoch 9/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2658 - accuracy: 0.9014 - val_loss: 0.3286 - val_accuracy: 0.8839
# Epoch 10/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2596 - accuracy: 0.9043 - val_loss: 0.3394 - val_accuracy: 0.8781

# %% [markdown]
# ## Evaluate the model

# %%
loss, accuracy = model_1_layer_500_nodes.evaluate(X_test, Y_test, verbose=0)
print('Test accuracy:', accuracy)
# Out:
# Test accuracy: 0.8780999779701233

# %% [markdown]
# Plot the accuracy and loss metrics of the model.

# %%
fig = plt.figure()
plt.subplot(2,1,1)
plt.plot(history_1_layer_500_nodes.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(history_1_layer_500_nodes.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()

# %%
predicted_classes = model_1_layer_500_nodes.predict(X_test)
predicted_classes = [np.argmax(softmaxArray) for softmaxArray in predicted_classes]
Y_True = [np.argmax(softmaxArray) for softmaxArray in Y_test]

correct_indices = np.where(np.array(predicted_classes) == np.array(Y_True))[0]
incorrect_indices = np.where(np.array(predicted_classes) != np.array(Y_True))[0]
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %%
plt.figure()
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[correct].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[correct], y_test[correct]))
plt.suptitle("Correct Predictions")  
plt.tight_layout()
    
plt.figure()
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[incorrect].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[incorrect], y_test[incorrect]))
plt.suptitle("Incorrect Predictions")
plt.tight_layout()

# %% [markdown]
# ## Two Layer And 100 Nodes

# %%
model_2_layer_100_nodes = Sequential()
model_2_layer_100_nodes.add(Dense(100, input_shape=(784,))) 
model_2_layer_100_nodes.add(Activation('relu'))
model_2_layer_100_nodes.add(Dropout(0.2))
model_2_layer_100_nodes.add(Dense(100, input_shape=(784,))) 
model_2_layer_100_nodes.add(Activation('relu'))
model_2_layer_100_nodes.add(Dropout(0.2))
model_2_layer_100_nodes.add(Dense(10))
model_2_layer_100_nodes.add(Activation('softmax'))
model_2_layer_100_nodes.summary()
model_2_layer_100_nodes.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history_2_layer_100_nodes = model_2_layer_100_nodes.fit(X_train, Y_train, batch_size=128, epochs=10, verbose=1, validation_data=(X_test, Y_test))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 100)               78500
#
#  activation_6 (Activation)   (None, 100)               0
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense_7 (Dense)             (None, 100)               10100
#
#  activation_7 (Activation)   (None, 100)               0
#
#  dropout_4 (Dropout)         (None, 100)               0
#
#  dense_8 (Dense)             (None, 10)                1010
#
#  activation_8 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 89610 (350.04 KB)
# Trainable params: 89610 (350.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 3s 5ms/step - loss: 0.6550 - accuracy: 0.7682 - val_loss: 0.4654 - val_accuracy: 0.8305
# Epoch 2/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4417 - accuracy: 0.8415 - val_loss: 0.4116 - val_accuracy: 0.8491
# Epoch 3/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3991 - accuracy: 0.8556 - val_loss: 0.3823 - val_accuracy: 0.8616
# Epoch 4/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3769 - accuracy: 0.8635 - val_loss: 0.3763 - val_accuracy: 0.8637
# Epoch 5/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3585 - accuracy: 0.8692 - val_loss: 0.3695 - val_accuracy: 0.8661
# Epoch 6/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3436 - accuracy: 0.8737 - val_loss: 0.3526 - val_accuracy: 0.8739
# Epoch 7/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3368 - accuracy: 0.8774 - val_loss: 0.3549 - val_accuracy: 0.8739
# Epoch 8/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3271 - accuracy: 0.8802 - val_loss: 0.3425 - val_accuracy: 0.8776
# Epoch 9/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3181 - accuracy: 0.8816 - val_loss: 0.3468 - val_accuracy: 0.8769
# Epoch 10/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3095 - accuracy: 0.8865 - val_loss: 0.3441 - val_accuracy: 0.8782

# %% [markdown]
# ## Evaluate the model

# %%
loss, accuracy = model_2_layer_100_nodes.evaluate(X_test, Y_test, verbose=0)
print('Test accuracy:', accuracy)
# Out:
# Test accuracy: 0.8781999945640564

# %% [markdown]
# Plot the accuracy and loss metrics of the model.

# %%
fig = plt.figure()
plt.subplot(2,1,1)
plt.plot(history_2_layer_100_nodes.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(history_2_layer_100_nodes.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()

# %%
predicted_classes = model_2_layer_100_nodes.predict(X_test)
predicted_classes = [np.argmax(softmaxArray) for softmaxArray in predicted_classes]
Y_True = [np.argmax(softmaxArray) for softmaxArray in Y_test]

correct_indices = np.where(np.array(predicted_classes) == np.array(Y_True))[0]
incorrect_indices = np.where(np.array(predicted_classes) != np.array(Y_True))[0]
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
plt.figure()
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[correct].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[correct], y_test[correct]))
plt.suptitle("Correct Predictions")  
plt.tight_layout()
    
plt.figure()
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[incorrect].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[incorrect], y_test[incorrect]))
plt.suptitle("Incorrect Predictions")
plt.tight_layout()

# %% [markdown]
# ## Two Layer And 300 Nodes

# %%
model_2_layer_300_nodes = Sequential()
model_2_layer_300_nodes.add(Dense(300, input_shape=(784,))) 
model_2_layer_300_nodes.add(Activation('relu'))
model_2_layer_300_nodes.add(Dropout(0.2))
model_2_layer_300_nodes.add(Dense(300, input_shape=(784,))) 
model_2_layer_300_nodes.add(Activation('relu'))
model_2_layer_300_nodes.add(Dropout(0.2))
model_2_layer_300_nodes.add(Dense(10))
model_2_layer_300_nodes.add(Activation('softmax'))
model_2_layer_300_nodes.summary()
model_2_layer_300_nodes.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history_2_layer_300_nodes = model_2_layer_300_nodes.fit(X_train, Y_train, batch_size=128, epochs=10, verbose=1, validation_data=(X_test, Y_test))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 300)               235500
#
#  activation_9 (Activation)   (None, 300)               0
#
#  dropout_5 (Dropout)         (None, 300)               0
#
#  dense_10 (Dense)            (None, 300)               90300
#
#  activation_10 (Activation)  (None, 300)               0
#
#  dropout_6 (Dropout)         (None, 300)               0
#
#  dense_11 (Dense)            (None, 10)                3010
#
#  activation_11 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 328810 (1.25 MB)
# Trainable params: 328810 (1.25 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 4s 7ms/step - loss: 0.5450 - accuracy: 0.8041 - val_loss: 0.4134 - val_accuracy: 0.8490
# Epoch 2/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3928 - accuracy: 0.8562 - val_loss: 0.3978 - val_accuracy: 0.8513
# Epoch 3/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3566 - accuracy: 0.8695 - val_loss: 0.3684 - val_accuracy: 0.8692
# Epoch 4/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3319 - accuracy: 0.8789 - val_loss: 0.3460 - val_accuracy: 0.8761
# Epoch 5/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3159 - accuracy: 0.8838 - val_loss: 0.3430 - val_accuracy: 0.8745
# Epoch 6/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3049 - accuracy: 0.8865 - val_loss: 0.3378 - val_accuracy: 0.8761
# Epoch 7/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2957 - accuracy: 0.8899 - val_loss: 0.3342 - val_accuracy: 0.8799
# Epoch 8/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2843 - accuracy: 0.8940 - val_loss: 0.3244 - val_accuracy: 0.8846
# Epoch 9/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2764 - accuracy: 0.8966 - val_loss: 0.3189 - val_accuracy: 0.8853
# Epoch 10/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2667 - accuracy: 0.8993 - val_loss: 0.3205 - val_accuracy: 0.8840

# %% [markdown]
# ## Evaluate the model

# %%
loss, accuracy = model_2_layer_300_nodes.evaluate(X_test, Y_test, verbose=0)
print('Test accuracy:', accuracy)
# Out:
# Test accuracy: 0.8840000033378601

# %% [markdown]
# Plot the accuracy and loss metrics of the model.

# %%
fig = plt.figure()
plt.subplot(2,1,1)
plt.plot(history_2_layer_300_nodes.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(history_2_layer_300_nodes.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()

# %%
predicted_classes = model_2_layer_300_nodes.predict(X_test)
predicted_classes = [np.argmax(softmaxArray) for softmaxArray in predicted_classes]
Y_True = [np.argmax(softmaxArray) for softmaxArray in Y_test]

correct_indices = np.where(np.array(predicted_classes) == np.array(Y_True))[0]
incorrect_indices = np.where(np.array(predicted_classes) != np.array(Y_True))[0]
# Out:
# 313/313 [==============================] - 1s 1ms/step

# %%
plt.figure()
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[correct].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[correct], y_test[correct]))
plt.suptitle("Correct Predictions")  
plt.tight_layout()
    
plt.figure()
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[incorrect].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[incorrect], y_test[incorrect]))
plt.suptitle("Incorrect Predictions")
plt.tight_layout()

# %% [markdown]
# ## Two Layer And 500 Nodes

# %%
model_2_layer_500_nodes = Sequential()
model_2_layer_500_nodes.add(Dense(500, input_shape=(784,))) 
model_2_layer_500_nodes.add(Activation('relu'))
model_2_layer_500_nodes.add(Dropout(0.2))
model_2_layer_500_nodes.add(Dense(500, input_shape=(784,))) 
model_2_layer_500_nodes.add(Activation('relu'))
model_2_layer_500_nodes.add(Dropout(0.2))
model_2_layer_500_nodes.add(Dense(10))
model_2_layer_500_nodes.add(Activation('softmax'))
model_2_layer_500_nodes.summary()
model_2_layer_500_nodes.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history_2_layer_500_nodes = model_2_layer_500_nodes.fit(X_train, Y_train, batch_size=128, epochs=10, verbose=1, validation_data=(X_test, Y_test))
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 500)               392500
#
#  activation_12 (Activation)  (None, 500)               0
#
#  dropout_7 (Dropout)         (None, 500)               0
#
#  dense_13 (Dense)            (None, 500)               250500
#
#  activation_13 (Activation)  (None, 500)               0
#
#  dropout_8 (Dropout)         (None, 500)               0
#
#  dense_14 (Dense)            (None, 10)                5010
#
#  activation_14 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 648010 (2.47 MB)
# Trainable params: 648010 (2.47 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 7s 14ms/step - loss: 0.5123 - accuracy: 0.8153 - val_loss: 0.4103 - val_accuracy: 0.8514
# Epoch 2/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.3828 - accuracy: 0.8595 - val_loss: 0.3748 - val_accuracy: 0.8625
# Epoch 3/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3470 - accuracy: 0.8706 - val_loss: 0.3653 - val_accuracy: 0.8684
# Epoch 4/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3249 - accuracy: 0.8798 - val_loss: 0.3626 - val_accuracy: 0.8677
# Epoch 5/10
# 469/469 [==============================] - 4s 10ms/step - loss: 0.3113 - accuracy: 0.8834 - val_loss: 0.3325 - val_accuracy: 0.8792
# Epoch 6/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.2986 - accuracy: 0.8887 - val_loss: 0.3459 - val_accuracy: 0.8765
# Epoch 7/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.2874 - accuracy: 0.8929 - val_loss: 0.3499 - val_accuracy: 0.8730
# Epoch 8/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.2780 - accuracy: 0.8961 - val_loss: 0.3287 - val_accuracy: 0.8793
# Epoch 9/10
# 469/469 [==============================] - 4s 10ms/step - loss: 0.2696 - accuracy: 0.8985 - val_loss: 0.3138 - val_accuracy: 0.8877
# Epoch 10/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2631 - accuracy: 0.9001 - val_loss: 0.3283 - val_accuracy: 0.8839

# %% [markdown]
# ## Evaluate the model

# %%
loss, accuracy = model_2_layer_500_nodes.evaluate(X_test, Y_test, verbose=0)
print('Test accuracy:', accuracy)
# Out:
# Test accuracy: 0.883899986743927

# %% [markdown]
# Plot the accuracy and loss metrics of the model.

# %%
fig = plt.figure()
plt.subplot(2,1,1)
plt.plot(history_2_layer_500_nodes.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(history_2_layer_500_nodes.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()

# %%
predicted_classes = model_2_layer_500_nodes.predict(X_test)
predicted_classes = [np.argmax(softmaxArray) for softmaxArray in predicted_classes]
Y_True = [np.argmax(softmaxArray) for softmaxArray in Y_test]

correct_indices = np.where(np.array(predicted_classes) == np.array(Y_True))[0]
incorrect_indices = np.where(np.array(predicted_classes) != np.array(Y_True))[0]
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %%
plt.figure()
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[correct].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[correct], y_test[correct]))
plt.suptitle("Correct Predictions")  
plt.tight_layout()
    
plt.figure()
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[incorrect].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[incorrect], y_test[incorrect]))
plt.suptitle("Incorrect Predictions")
plt.tight_layout()
